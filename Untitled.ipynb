# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import sys
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)

# %%
sys.path.append('../data')

# %%
data_dir = "/Users/tcai/gdrive/git_repo/image_caption_generations/data"
data_type = "val2017"
annFile='{}/annotations/instances_{}.json'.format(data_dir,data_type)

# initialize COCO api for instance annotations
coco=COCO(annFile)

# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('COCO categories: \n{}\n'.format(' '.join(nms)))

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
# Out:
# loading annotations into memory...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-271ecd459b81> in <module>
#       4
#       5 # initialize COCO api for instance annotations
# ----> 6 coco=COCO(annFile)
#       7
#       8 # display COCO categories and supercategories
#
# /usr/local/lib/python3.7/site-packages/pycocotools/coco.py in __init__(self, annotation_file)
#      82             print('loading annotations into memory...')
#      83             tic = time.time()
# ---> 84             dataset = json.load(open(annotation_file, 'r'))
#      85             assert type(dataset)==dict, 'annotation file format {} not supported'.format(type(dataset))
#      86             print('Done (t={:0.2f}s)'.format(time.time()- tic))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/tcai/gdrive/git_repo/image_caption_generations/data/annotations/instances_val2017.json'
